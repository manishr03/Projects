# %%
import pandas as pd
import numpy as np 
import os

# %%
os.chdir('/Users/manishrathor/Documents/Data Science Projects')

# %%
df = pd.read_csv('matches.csv', index_col=0)
df.head()
# Out:
#          Date   Time            Comp        Round  Day Venue Result  GF  GA  \
# 1  2022-08-07  16:30  Premier League  Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League  Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League  Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League  Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League  Matchweek 5  Wed  Home      W   6   0
#
#           Opponent  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 1         West Ham  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1     1
# 2      Bournemouth  ...  Match Report    NaN  19.0   7.0  17.5  0.0  0     0
# 3    Newcastle Utd  ...  Match Report    NaN  21.0  10.0  16.2  1.0  0     0
# 4   Crystal Palace  ...  Match Report    NaN  18.0   5.0  14.1  0.0  0     0
# 5  Nott'ham Forest  ...  Match Report    NaN  17.0   9.0  14.8  0.0  0     0
#
#    Season             Team
# 1    2023  Manchester City
# 2    2023  Manchester City
# 3    2023  Manchester City
# 4    2023  Manchester City
# 5    2023  Manchester City
#
# [5 rows x 27 columns]

# %%
# checking for missing data - there should be 2280 matches over three seasons
print(df.shape)
38 * 20 * 3
# no missing data
# Out:
# (2280, 27)
# 2280

# %%
# checking data types - our model can only take numeric type 
df.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain', 'Formation',
#        'Referee', 'Match Report', 'Notes', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt', 'Season', 'Team'],
#       dtype='object')

# %%
# dropping data we don't need
df = df.drop(['Comp', 'Round', 'Captain', 'Formation', 'Referee', 'Match Report', 'Notes', 'Season'], axis = 1)
df
# Out:
#           Date   Time  Day Venue Result  GF  GA         Opponent   xG  xGA  \
# 1   2022-08-07  16:30  Sun  Away      W   2   0         West Ham  2.2  0.5
# 2   2022-08-13  15:00  Sat  Home      W   4   0      Bournemouth  1.7  0.1
# 3   2022-08-21  16:30  Sun  Away      D   3   3    Newcastle Utd  2.1  1.8
# 4   2022-08-27  15:00  Sat  Home      W   4   2   Crystal Palace  2.2  0.1
# 5   2022-08-31  19:30  Wed  Home      W   6   0  Nott'ham Forest  3.3  0.7
# ..         ...    ...  ...   ...    ...  ..  ..              ...  ...  ...
# 38  2021-05-02  19:15  Sun  Away      L   0   4        Tottenham  0.5  2.2
# 39  2021-05-08  15:00  Sat  Home      L   0   2   Crystal Palace  0.7  2.0
# 40  2021-05-16  19:00  Sun  Away      W   1   0          Everton  1.2  1.4
# 41  2021-05-19  18:00  Wed  Away      L   0   1    Newcastle Utd  0.9  1.6
# 42  2021-05-23  16:00  Sun  Home      W   1   0          Burnley  0.5  1.1
#
#     Poss  Attendance    Sh   SoT  Dist   FK  PK  PKatt              Team
# 1   75.0     62443.0  13.0   1.0  18.7  1.0   1      1   Manchester City
# 2   67.0     53453.0  19.0   7.0  17.5  0.0   0      0   Manchester City
# 3   69.0     52258.0  21.0  10.0  16.2  1.0   0      0   Manchester City
# 4   74.0     53112.0  18.0   5.0  14.1  0.0   0      0   Manchester City
# 5   74.0     53409.0  17.0   9.0  14.8  0.0   0      0   Manchester City
# ..   ...         ...   ...   ...   ...  ...  ..    ...               ...
# 38  34.0         NaN   8.0   1.0  18.2  0.0   0      0  Sheffield United
# 39  50.0         NaN   7.0   0.0  13.4  1.0   0      0  Sheffield United
# 40  38.0         NaN  10.0   3.0  18.5  0.0   0      0  Sheffield United
# 41  49.0     10000.0  11.0   1.0  18.3  1.0   0      0  Sheffield United
# 42  43.0      5000.0  12.0   3.0  17.4  0.0   0      0  Sheffield United
#
# [2280 rows x 19 columns]

# %%
df.dtypes
# Out:
# Date           object
# Time           object
# Day            object
# Venue          object
# Result         object
# GF              int64
# GA              int64
# Opponent       object
# xG            float64
# xGA           float64
# Poss          float64
# Attendance    float64
# Sh            float64
# SoT           float64
# Dist          float64
# FK            float64
# PK              int64
# PKatt           int64
# Team           object
# dtype: object

# %%
# converting data to datetime type
df.Date = pd.to_datetime(df.Date)

#converting time to an integer from 0-23
df.Time = df.Time.replace(":.+", "", regex = True).astype(int)

# converting venue to integer (0 or 1)
df.Venue = df.Venue.astype('category').cat.codes

# converting day to integer (1 - 7)
day_codes = {
    'Mon' : 1,
    'Tue' : 2,
    'Wed' : 3,
    'Thu' : 4,
    'Fri' : 5,
    'Sat' : 6, 
    'Sun' : 7
}
df.Day = df.Day.map(day_codes)

# converting result to integers
result_codes = {
    'W' : 2,
    'D' : 1,
    'L' : 0
}
df.Result = df.Result.map(result_codes)

# %%
df.head()
# Out:
#         Date  Time  Day  Venue  Result  GF  GA         Opponent   xG  xGA  \
# 1 2022-08-07    16    7      0       2   2   0         West Ham  2.2  0.5
# 2 2022-08-13    15    6      1       2   4   0      Bournemouth  1.7  0.1
# 3 2022-08-21    16    7      0       1   3   3    Newcastle Utd  2.1  1.8
# 4 2022-08-27    15    6      1       2   4   2   Crystal Palace  2.2  0.1
# 5 2022-08-31    19    3      1       2   6   0  Nott'ham Forest  3.3  0.7
#
#    Poss  Attendance    Sh   SoT  Dist   FK  PK  PKatt             Team
# 1  75.0     62443.0  13.0   1.0  18.7  1.0   1      1  Manchester City
# 2  67.0     53453.0  19.0   7.0  17.5  0.0   0      0  Manchester City
# 3  69.0     52258.0  21.0  10.0  16.2  1.0   0      0  Manchester City
# 4  74.0     53112.0  18.0   5.0  14.1  0.0   0      0  Manchester City
# 5  74.0     53409.0  17.0   9.0  14.8  0.0   0      0  Manchester City

# %% [markdown]
# ## Encoding Summary:
#
# 1. Time: I simply stripped the minute values from the time data
# 2. Venue: 0 = Away, 1 = Home
#
# The rest are self explanatory from the code above

# %%
# dropping missing values 
df.isna().sum()
# Out:
# Date            0
# Time            0
# Day             0
# Venue           0
# Result          0
# GF              0
# GA              0
# Opponent        0
# xG              0
# xGA             0
# Poss            0
# Attendance    698
# Sh              0
# SoT             0
# Dist            1
# FK              0
# PK              0
# PKatt           0
# Team            0
# dtype: int64

# %%
df = df.drop(['Attendance'], axis = 1)
print(df.shape)
df.head()
# Out:
# (2280, 18)
#         Date  Time  Day  Venue  Result  GF  GA         Opponent   xG  xGA  \
# 1 2022-08-07    16    7      0       2   2   0         West Ham  2.2  0.5
# 2 2022-08-13    15    6      1       2   4   0      Bournemouth  1.7  0.1
# 3 2022-08-21    16    7      0       1   3   3    Newcastle Utd  2.1  1.8
# 4 2022-08-27    15    6      1       2   4   2   Crystal Palace  2.2  0.1
# 5 2022-08-31    19    3      1       2   6   0  Nott'ham Forest  3.3  0.7
#
#    Poss    Sh   SoT  Dist   FK  PK  PKatt             Team
# 1  75.0  13.0   1.0  18.7  1.0   1      1  Manchester City
# 2  67.0  19.0   7.0  17.5  0.0   0      0  Manchester City
# 3  69.0  21.0  10.0  16.2  1.0   0      0  Manchester City
# 4  74.0  18.0   5.0  14.1  0.0   0      0  Manchester City
# 5  74.0  17.0   9.0  14.8  0.0   0      0  Manchester City

# %%
df = df[df.Dist.isna() != True]
df.shape
# Out:
# (2279, 18)

# %%
print(len(df.Opponent.unique()))
df.Opponent.unique()
# Out:
# 25
# array(['West Ham', 'Bournemouth', 'Newcastle Utd', 'Crystal Palace',
#        "Nott'ham Forest", 'Aston Villa', 'Wolves', 'Manchester Utd',
#        'Southampton', 'Liverpool', 'Brighton', 'Leicester City', 'Fulham',
#        'Brentford', 'Leeds United', 'Everton', 'Chelsea', 'Tottenham',
#        'Arsenal', 'Manchester City', 'Norwich City', 'Burnley', 'Watford',
#        'Sheffield Utd', 'West Brom'], dtype=object)

# %%
print(len(df.Team.unique()))
df.Team.unique()
# Out:
# 25
# array(['Manchester City', 'Arsenal', 'Manchester United',
#        'Newcastle United', 'Liverpool', 'Brighton and Hove Albion',
#        'Aston Villa', 'Tottenham Hotspur', 'Brentford', 'Fulham',
#        'Crystal Palace', 'Chelsea', 'Wolverhampton Wanderers',
#        'West Ham United', 'Bournemouth', 'Nottingham Forest', 'Everton',
#        'Leicester City', 'Leeds United', 'Southampton', 'Burnley',
#        'Watford', 'Norwich City', 'West Bromwich Albion',
#        'Sheffield United'], dtype=object)

# %%
# standardizing team names across team/opponent columns

class MissingDict(dict):
    __missing__ = lambda self, key: key

club_names = {
    'West Ham' : 'West Ham United',
    'Newcastle Utd' : 'Newcastle United',
    'Nott\'ham Forest' : 'Nottingham Forest', 
    'Wolves' : 'Wolverhampton Wanderers',
    'Manchester Utd' : 'Manchester United',
    'Brighton' : 'Brighton and Hove Albion',
    'Tottenham' : 'Tottenham Hotspur'
}

map = MissingDict(**club_names)
df.Opponent = df.Opponent.map(map)

# %%
df.head()
# Out:
#         Date  Time  Day  Venue  Result  GF  GA           Opponent   xG  xGA  \
# 1 2022-08-07    16    7      0       2   2   0    West Ham United  2.2  0.5
# 2 2022-08-13    15    6      1       2   4   0        Bournemouth  1.7  0.1
# 3 2022-08-21    16    7      0       1   3   3   Newcastle United  2.1  1.8
# 4 2022-08-27    15    6      1       2   4   2     Crystal Palace  2.2  0.1
# 5 2022-08-31    19    3      1       2   6   0  Nottingham Forest  3.3  0.7
#
#    Poss    Sh   SoT  Dist   FK  PK  PKatt             Team
# 1  75.0  13.0   1.0  18.7  1.0   1      1  Manchester City
# 2  67.0  19.0   7.0  17.5  0.0   0      0  Manchester City
# 3  69.0  21.0  10.0  16.2  1.0   0      0  Manchester City
# 4  74.0  18.0   5.0  14.1  0.0   0      0  Manchester City
# 5  74.0  17.0   9.0  14.8  0.0   0      0  Manchester City

# %%
# checking for missing values 
df.isna().sum()
# Out:
# Date        0
# Time        0
# Day         0
# Venue       0
# Result      0
# GF          0
# GA          0
# Opponent    0
# xG          0
# xGA         0
# Poss        0
# Sh          0
# SoT         0
# Dist        0
# FK          0
# PK          0
# PKatt       0
# Team        0
# dtype: int64

# %%
# creating our features and target 
features = df[['Time', 'Day', 'Venue', 'xG', 'xGA', 'Poss', 'Sh', 'SoT', 'Dist', 'FK', 'PK', 'PKatt']]
target = df['Result']

# %%
# converting the target to categorical type for classification

from tensorflow.keras.utils import to_categorical

target = to_categorical(target, num_classes= 3)

# %%
from sklearn.model_selection import train_test_split

# %%
# splitting the dataset
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size= 0.2, random_state= 42)

# %%
# checking the shape of the data
split = [x_train, x_test, y_train, y_test]

for val in split:
    print(val.shape)
# Out:
# (1823, 12)
# (456, 12)
# (1823, 3)
# (456, 3)

# %% [markdown]
# ### Creating and Training the Neural Network

# %%
# importing dependencies
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
# implementing the model architecture

# this will be a sequential model - we can add layers step-by-step
# we will also use ReLU activation
model = Sequential()
# first hidden layer will have 128 neurons
model.add(Dense(128, input_shape = (x_train.shape[1],), activation = 'relu'))
# second hidden layer will have 64 neurons
model.add(Dense(64, activation = 'relu'))
#third hidden layer will have 32 neurons
model.add(Dense(32, activation = 'relu'))
# ouput layer will have 1 neuron
model.add(Dense(3, activation = 'softmax'))

# %%
# compiling the model 

# using the Adam optimizer
# using the mse as the loss function
# measuring model performance with mse
optimizer = Adam(learning_rate = 0.001)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.

# %%
# training the model

model_fit = model.fit(x_train, y_train, epochs = 10, batch_size = 32, validation_split= 0.2)
# Out:
# Epoch 1/10
# 46/46 [==============================] - 0s 3ms/step - loss: 1.0641 - accuracy: 0.4979 - val_loss: 0.9739 - val_accuracy: 0.5342
# Epoch 2/10
# 46/46 [==============================] - 0s 932us/step - loss: 0.9900 - accuracy: 0.5288 - val_loss: 0.9718 - val_accuracy: 0.5726
# Epoch 3/10
# 46/46 [==============================] - 0s 935us/step - loss: 0.9333 - accuracy: 0.5700 - val_loss: 0.9338 - val_accuracy: 0.5753
# Epoch 4/10
# 46/46 [==============================] - 0s 878us/step - loss: 0.9357 - accuracy: 0.5830 - val_loss: 1.0016 - val_accuracy: 0.5562
# Epoch 5/10
# 46/46 [==============================] - 0s 899us/step - loss: 0.8984 - accuracy: 0.5940 - val_loss: 0.9041 - val_accuracy: 0.5808
# Epoch 6/10
# 46/46 [==============================] - 0s 1ms/step - loss: 0.8637 - accuracy: 0.6118 - val_loss: 0.9203 - val_accuracy: 0.5507
# Epoch 7/10
# 46/46 [==============================] - 0s 938us/step - loss: 0.8576 - accuracy: 0.6118 - val_loss: 0.8897 - val_accuracy: 0.5205
# Epoch 8/10
# 46/46 [==============================] - 0s 2ms/step - loss: 0.8523 - accuracy: 0.6104 - val_loss: 0.8473 - val_accuracy: 0.6027
# Epoch 9/10
# 46/46 [==============================] - 0s 911us/step - loss: 0.8343 - accuracy: 0.6351 - val_loss: 0.8633 - val_accuracy: 0.6110
# Epoch 10/10
# 46/46 [==============================] - 0s 851us/step - loss: 0.8668 - accuracy: 0.6248 - val_loss: 0.8550 - val_accuracy: 0.5699

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Testing Accuracy: {accuracy}")
# Out:
# 15/15 [==============================] - 0s 520us/step - loss: 0.9099 - accuracy: 0.5899
# Testing Accuracy: 0.5899122953414917
